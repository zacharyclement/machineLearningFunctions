# %%
#import tensorflow as tf
import pymysql as db
import pandas as pd

# %%
conn = db.connect(host='192.168.2.88', port=3306, user='zach', passwd='1qaz!QAZ', db='stratagem_matomo')

# %%
query_action = 'SELECT * FROM stratagem_matomo.matomo_log_action'

# %%
df_action = pd.read_sql_query(query_action, conn)

# %%
df_action
# Out:
#      idaction                                              name        hash  \
# 0           1                                StrataGem by Rigil   469154411
# 1           2                            192.168.2.88:8080/app/  4229368114
# 2           3                                   localhost:4200/  3504196112
# 3           4                            192.168.2.89:8080/app/  1033492210
# 4           5                            192.168.2.16:8080/app/   868751525
# 5           6                           192.168.2.88:8080//app/  2210202388
# 6           7                                 192.168.2.31/app/  1900162707
# 7           8                          206.205.101.39:8080/app/   787866642
# 8           9                                    localhost/app/  3892997072
# 9          10                               localhost/app/Login  2502629245
# 10         11                               localhost:4200/app/   212160010
# ...

# %%
df_action_name = df_action.groupby(['name']).agg({'name': 'count'}).sort_values(by='name', ascending=False)
# Out:
# C:\Users\zacha\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'name' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   """Entry point for launching an IPython kernel.

# %%
df_action_name
# Out:
#                                                     name
# name
# Hindi                                                  2
# 192.168.2.16:8080/app/                                 1
# com.rigil.matchgame/Home                               1
# com.rigil.matchgame-enterprise/Home/Review             1
# com.rigil.matchgame-enterprise/Home/Pick%20Livery      1
# com.rigil.matchgame-enterprise/Home/Pick%20Image       1
# com.rigil.matchgame-enterprise/Home/Pick%20Hindi       1
# com.rigil.matchgame-enterprise/Home/Match%20Pro        1
# com.rigil.matchgame-enterprise/Home/LeaderBoard        1
# com.rigil.matchgame-enterprise/Home/Info               1
# com.rigil.matchgame-enterprise/Home/Evalaute           1
# com.rigil.matchgame-enterprise/Home                    1
# com.rigil.matchgame-enterprise/                        1
# com.rigil.aircraftvector/Home/Reference                1
# com.rigil.aircraftvector/Home/Compass%20Headings/1     1
# ...

# %%
df_action_type = df_action.groupby(['type']).agg({'type': 'count'}).sort_values(by='type', ascending=False)
# Out:
# C:\Users\zacha\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'type' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   """Entry point for launching an IPython kernel.

# %%
df_action_type
# Out:
#       type
# type
# 1       48
# 4       18
# 10      16
# 12      13
# 11       8

# %%
df_action[df_action['type'] == 11]
# Out:
#     idaction        name        hash  type  url_prefix
# 22        23         N90  2904081614    11         NaN
# 25        26     Correct    78467623    11         NaN
# 27        28   Completed  3087654605    11         NaN
# 28        29   Incorrect   119908286    11         NaN
# 74        75      TRACON  3556721781    11         NaN
# 82        83   Languages   572576218    11         NaN
# 89        90    Complete  3138499189    11         NaN
# 92        93  Incomplete   851513696    11         NaN

# %%
df_action[df_action['type'] == 12]
# Out:
#      idaction                               name        hash  type  url_prefix
# 24         25         Callsign &amp; 3 Letter ID  2829389562    12         NaN
# 26         27   N90 / Callsign &amp; 3 Letter ID  2507404414    12         NaN
# 42         43                    CompassHeadings  2511908534    12         NaN
# 44         45            Compass Headings-Level0  1204011267    12         NaN
# 53         54                    ClosestHeadings   715387549    12         NaN
# 62         63            Compass Headings-Level1   818213269    12         NaN
# 76         77                    Aircraft Livery  2343142852    12         NaN
# 78         79           TRACON / Aircraft Livery  1190624191    12         NaN
# 84         85                              Hindi  2671365481    12         NaN
# 86         87                  Languages / Hindi  3721580671    12         NaN
# 91         92  TRACON/Callsign &amp; 3 Letter ID  1078298339    12         NaN
# ...
