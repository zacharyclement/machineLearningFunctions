# %%
import tensorflow as tf
import pymysql as db
import pandas as pd

# %%
conn = db.connect(host='192.168.2.88', port=3306, user='zach', passwd='1qaz!QAZ', db='old')

# %%
query_action = 'SELECT * FROM old.matomo_log_action'

# %%
df_action = pd.read_sql_query(query_action, conn)

# %%
df_action
# Out:
#      idaction                                               name        hash  \
# 0           1                                 StrataGem by Rigil   469154411
# 1           2                           206.205.101.39:8080/app/   787866642
# 2           3                                    localhost:4200/  3504196112
# 3           4                           206.205.101.52:8081/app/   699733267
# 4           5                             10.22.16.181:8080/app/  1869514949
# 5           6                                     Login/MenuView  1628449468
# 6           7                com.rigil.matchgame1/Login/MenuView   513793483
# 7           8                                               menu  2097494675
# 8           9           com.architdhupar.sganalyticsexample/menu  3750448386
# 9          10                              com.rigil.matchgame1/  1833139562
# 10         11                                  LeaderBoardAction  1917778110
# 11         12                                       TestCategory  1325569498
# 12         13                                        LeaderBoard  1601434240
# 13         14                                       ReviewAction  3253179099
# 14         15                                             Review  2129626352
# 15         16                                     EvaluateAction  3167185038
# 16         17                                           Evaluate  2012375262
# 17         18                 com.rigil.matchgame/Login/MenuView  1757713057
# 18         19                               com.rigil.matchgame/  1811729535
# 19         20                                     EvalauteAction  1672370785
# 20         21                                           Evalaute  3014042554
# 21         22                                               Home  3521422318
# 22         23                           com.rigil.matchgame/Home   409234017
# 23         24                                      Home/Evalaute  2508116631
# 24         25                  com.rigil.matchgame/Home/Evalaute  4153074843
# 25         26                                   Home/LeaderBoard  3519690052
# 26         27               com.rigil.matchgame/Home/LeaderBoard  3944508210
# 27         28                                        Home/Review  3827282609
# 28         29                    com.rigil.matchgame/Home/Review   369456840
# 29         30                                         Home/Match  4095679872
# ..        ...                                                ...         ...
# 161       162  com.rigil.aircraftvector/Home/Relative%20headi...  3863886556
# 162       163                           Relative headings-Level3  4117589733
# 163       164                        Relative headings-Challenge  3801376523
# 164       165                          Simulated Aircraft-Level1  1194529966
# 165       166                          Home/Simulated Aircraft/2  3368860138
# 166       167  com.rigil.aircraftvector/Home/Simulated%20Airc...  4268770041
# 167       168                          Simulated Aircraft-Level2  3728360724
# 168       169                          Simulated Aircraft-Level3  2839377282
# 169       170                    Home/Compass Headings/Challenge  1094564073
# 170       171  com.rigil.aircraftvector/Home/Compass%20Headin...  1447503551
# 171       172                                  Home/Wind Effects  2837790282
# 172       173       com.rigil.aircraftvector/Home/Wind%20Effects   274927676
# 173       174                                Home/Wind Effects/1  3387701673
# 174       175     com.rigil.aircraftvector/Home/Wind%20Effects/1  1818186576
# 175       176                                Wind Effects-Level1  2711386501
# 176       177                     Home/Simulated Aircraft/Level1  2811125127
# 177       178  com.rigil.aircraftvector/Home/Simulated%20Airc...  2498869106
# 178       179                                         Pick image  2033750258
# 179       180                                 Pick Pronunciation  3358487078
# 180       181                                          Mission-1  2459742241
# 181       182                                      NumberOfMoves  1813465589
# 182       183                                            Success  2696799790
# 183       184                                          Mission-1  2459742241
# 184       185                                          Mission-2   194371995
# 185       186                                      Home/Mision 2  2324131392
# 186       187   com.rigil.advancedaircraftvector/Home/Mision%202  1228678282
# 187       188                                      Home/Mision 3  4253048534
# 188       189   com.rigil.advancedaircraftvector/Home/Mision%203  1044059164
# 189       190                                          Mission-3  2089996557
# 190       191                                localhost:4200/app/   212160010
#
#      type  url_prefix
# 0       4         NaN
# 1       1         0.0
# 2       1         0.0
# 3       1         0.0
# 4       1         0.0
# 5       4         NaN
# 6       1         0.0
# 7       4         NaN
# 8       1         0.0
# 9      10         0.0
# 10     11         NaN
# 11     10         NaN
# 12     12         NaN
# 13     11         NaN
# 14     12         NaN
# 15     11         NaN
# 16     12         NaN
# 17      1         0.0
# 18     10         0.0
# 19     11         NaN
# 20     12         NaN
# 21      4         NaN
# 22      1         0.0
# 23      4         NaN
# 24      1         0.0
# 25      4         NaN
# 26      1         0.0
# 27      4         NaN
# 28      1         0.0
# 29      4         NaN
# ..    ...         ...
# 161     1         0.0
# 162    12         NaN
# 163    12         NaN
# 164    12         NaN
# 165     4         NaN
# 166     1         0.0
# 167    12         NaN
# 168    12         NaN
# 169     4         NaN
# 170     1         0.0
# 171     4         NaN
# 172     1         0.0
# 173     4         NaN
# 174     1         0.0
# 175    12         NaN
# 176     4         NaN
# 177     1         0.0
# 178    10         NaN
# 179    10         NaN
# 180    10         NaN
# 181    12         NaN
# 182    11         NaN
# 183    12         NaN
# 184    10         NaN
# 185     4         NaN
# 186     1         0.0
# 187     4         NaN
# 188     1         0.0
# 189    10         NaN
# 190     1         0.0
#
# [191 rows x 5 columns]
