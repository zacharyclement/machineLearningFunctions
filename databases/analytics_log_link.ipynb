# %%
import tensorflow as tf
import pymysql as db
import pandas as pd

# %%
conn = db.connect(host='192.168.2.88', port=3306, user='zach', passwd='1qaz!QAZ', db='old')

# %%
query_link = 'SELECT * FROM old.matomo_log_link_visit_action'

# %%
df_link = pd.read_sql_query(query_link, conn)

# %%
df_link
# Out:
#        idlink_va  idsite                         idvisitor  idvisit  \
# 0              1       1     b'\xdf+\xb50\xe8\x9c\x05\xe3'        1
# 1              2       1     b'\xdf+\xb50\xe8\x9c\x05\xe3'        1
# 2              3       1     b'\xd2\xa6)t\x8d\x98\x01\x8a'        2
# 3              4       1     b'\xd2\xa6)t\x8d\x98\x01\x8a'        3
# 4              5       1     b'\xd2\xa6)t\x8d\x98\x01\x8a'        3
# 5              6       1     b'\xd2\xa6)t\x8d\x98\x01\x8a'        3
# 6              7       1     b'\xd2\xa6)t\x8d\x98\x01\x8a'        3
# 7              8       1     b'\xd2\xa6)t\x8d\x98\x01\x8a'        3
# 8              9       1     b'\xd2\xa6)t\x8d\x98\x01\x8a'        4
# 9             10       1        b'U\xe5\x01@\x96\xab\xcdu'        5
# 10            11       1           b'\xda[\xae\x19j\xa9y#'        6
# 11            12       1  b'z\xa8\x17\xfa\xd4\xd3\xbf\x14'        7
# 12            13       1  b'\xa2\xdb\x10\xd8\xf5{\xc1\xac'        8
# ...
